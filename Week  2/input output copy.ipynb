# %%
# !ls
# Out:
# Untitled.ipynb     clean_data.csv     input output.ipynb

# %%
import pandas as pd

# %%
csv_df = pd.read_csv('clean_data.csv')

# %%
csv_df.head()
# Out:
#    Unnamed: 0                        Indicator     Group       State  \
# 0          19  Symptoms of Depressive Disorder  By State     Alabama
# 1          20  Symptoms of Depressive Disorder  By State      Alaska
# 2          21  Symptoms of Depressive Disorder  By State     Arizona
# 3          22  Symptoms of Depressive Disorder  By State    Arkansas
# 4          23  Symptoms of Depressive Disorder  By State  California
#
#      Subgroup Phase  Time Period     Time Period Label Time Period Start Date  \
# 0     Alabama     1            1  Apr 23 - May 5, 2020             04/23/2020
# 1      Alaska     1            1  Apr 23 - May 5, 2020             04/23/2020
# 2     Arizona     1            1  Apr 23 - May 5, 2020             04/23/2020
# 3    Arkansas     1            1  Apr 23 - May 5, 2020             04/23/2020
# 4  California     1            1  Apr 23 - May 5, 2020             04/23/2020
#
#   Time Period End Date  Value  Low CI  High CI Confidence Interval  \
# ...

# %%
csv_df = csv_df.drop('Unnamed: 0', axis=1)

# %%
csv_df.head()
# Out:
#                          Indicator     Group       State    Subgroup Phase  \
# 0  Symptoms of Depressive Disorder  By State     Alabama     Alabama     1
# 1  Symptoms of Depressive Disorder  By State      Alaska      Alaska     1
# 2  Symptoms of Depressive Disorder  By State     Arizona     Arizona     1
# 3  Symptoms of Depressive Disorder  By State    Arkansas    Arkansas     1
# 4  Symptoms of Depressive Disorder  By State  California  California     1
#
#    Time Period     Time Period Label Time Period Start Date  \
# 0            1  Apr 23 - May 5, 2020             04/23/2020
# 1            1  Apr 23 - May 5, 2020             04/23/2020
# 2            1  Apr 23 - May 5, 2020             04/23/2020
# 3            1  Apr 23 - May 5, 2020             04/23/2020
# 4            1  Apr 23 - May 5, 2020             04/23/2020
#
#   Time Period End Date  Value  Low CI  High CI Confidence Interval  \
# 0           05/05/2020   18.6    14.6     23.1         14.6 - 23.1
# ...
