# %% [markdown]
# # INPUT OUTPUT

# %%
import pandas as pd

# %%
# !ls
# Out:
# INPUT OUTPUT.ipynb Salaries.csv       example

# %% [markdown]
# ## HTML
#
# You may need to install htmllib5,lxml, and BeautifulSoup4. In your terminal/command prompt run:
#
#     pip install lxml
#     pip install html5lib
#     pip install BeautifulSoup4
#
# Then restart Jupyter Notebook.
# (or use pip install if you aren't using the Anaconda Distribution)
#
# Pandas can read table tabs off of html. For example:

# %%
df = pd.DataFrame({
    'a':[0,4,8,12],
    'b':[1,5,9,13],
    'c':[2,6,10,14],
    'd':[3,7,11,15]
})

# %%
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df.to_csv('Example.csv')

# %%
ls
# Out:
# Example.csv         INPUT OUTPUT.ipynb  Salaries.csv        example

# %%
df.to_excel('Excel_Sample.xlsx',sheet_name='Sheet1')

# %%
ls
# Out:
# Example.csv         INPUT OUTPUT.ipynb  example
# Excel_Sample.xlsx   Salaries.csv

# %%
excel_df = pd.read_excel('Excel_Sample.xlsx',sheet_name='Sheet1')

# %%
excel_df
# Out:
#    Unnamed: 0   a   b   c   d
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15

# %%
excel_df = excel_df.drop('Unnamed: 0',axis=1)

# %%
excel_df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
bank_data = pd.read_html('https://www.fdic.gov/resources/resolutions/bank-failures/failed-bank-list/')

# %%
bank_data[0]
# Out:
#                          Bank NameBank       CityCity StateSt  CertCert  \
# 0                        Citizens Bank       Sac City      IA      8758
# 1             Heartland Tri-State Bank        Elkhart      KS     25851
# 2                  First Republic Bank  San Francisco      CA     59017
# 3                       Signature Bank       New York      NY     57053
# 4                  Silicon Valley Bank    Santa Clara      CA     24735
# ..                                 ...            ...     ...       ...
# 563                 Superior Bank, FSB       Hinsdale      IL     32646
# 564                Malta National Bank          Malta      OH      6629
# 565    First Alliance Bank & Trust Co.     Manchester      NH     34264
# 566  National State Bank of Metropolis     Metropolis      IL      3815
# 567                   Bank of Honolulu       Honolulu      HI     21029
#
#                  Acquiring InstitutionAI Closing DateClosing  FundFund
# ...

# %%
import numpy as np
import random

# %%
artf_data = pd.DataFrame(np.random.randn(20,8),
                         index=[f'Row {i}' for i in range(20)],
                        columns=[f'Column {j}' for j in range(8)])

# %%
artf_data
# Out:
#         Column 0  Column 1  Column 2  Column 3  Column 4  Column 5  Column 6  \
# Row 0   1.911730  0.780423 -0.074907 -0.622894 -0.214272  0.333416  1.158573
# Row 1  -0.177559  0.422628 -0.951478  0.269730  1.389528 -0.870471 -0.384741
# Row 2  -0.334527  1.326016 -2.077619 -1.217260  0.236030  0.707230 -0.428468
# Row 3  -2.339653  1.452986  0.873856 -0.868733 -1.429149  1.450011 -0.605897
# Row 4   2.384532 -0.264431  0.299392  0.818531  1.540838  2.461713  0.615111
# Row 5   0.679718 -0.529288 -0.865267 -1.304228  0.019139  1.142150  0.728563
# Row 6  -1.186341 -1.329523  0.482960  0.156177 -1.466205  0.000410 -0.067396
# Row 7  -0.596637 -0.816875 -0.429648  1.227596 -0.449464 -1.616682  0.812820
# Row 8   0.102357 -0.456602 -0.575526 -0.117379 -0.939114  0.368697 -0.110682
# Row 9   0.715984  0.174152 -0.299103  1.412155  0.505193 -1.272709  0.086157
# Row 10  0.854356  0.703483  0.400553  1.121740  1.194422  1.880220  1.802460
# ...

# %%
artf_data = artf_data[artf_data['Column 1']> -0.1]

# %%
artf_data
# Out:
#         Column 0  Column 1  Column 2  Column 3  Column 4  Column 5  Column 6  \
# Row 0   0.545875  0.533535  1.725860 -1.460604 -0.481603  1.574198 -0.840646
# Row 2  -1.065062  0.589147  1.708825 -0.681546  0.695484  0.212477  1.526407
# Row 3  -1.289394  1.365697  1.142016 -0.319612 -0.765880  1.415476 -0.840594
# Row 9  -0.040211 -0.033899 -0.283069  0.529642  0.524963 -2.087780 -0.859269
# Row 11 -1.104479  0.404691 -0.050010 -1.412421 -0.751123  0.164513  1.541296
# Row 14 -0.395331  2.193387  0.452139 -0.012518  1.439188  0.379218  0.118441
# Row 16  0.360551  0.179904 -0.788902  0.765010  1.192573 -0.085337 -1.014284
# Row 17 -0.611876  1.572419 -2.012636 -0.604521 -1.243589 -0.405092  0.198681
# Row 18  0.353411  0.224971  1.403057 -0.067283 -1.760608  0.722903  2.039225
#
#         Column 7
# Row 0   1.143577
# Row 2   1.346652
# Row 3  -1.109766
# Row 9   0.081868
# Row 11 -0.909021
# Row 14 -0.155937
# Row 16  0.301778
# Row 17  1.629026
# Row 18  1.108925

# %%
artf_data['Column 1']> -0.1
# Out:
# Row 0     True
# Row 2     True
# Row 3     True
# Row 9     True
# Row 11    True
# Row 14    True
# Row 16    True
# Row 17    True
# Row 18    True
# Name: Column 1, dtype: bool
